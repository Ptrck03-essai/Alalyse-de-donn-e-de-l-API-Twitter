# %% [markdown]
# ## Act Report

# %% [markdown]
# > Ce rapport communique toutes les observations et affiche la ou les visualisations produites à partir de nos données.

# %% [markdown]
# > L'ensemble de données que nous avons préparé, analysé et visualisé est l'archive twitter de #WeRateDogs. C'est un compte twitter sur le quel les utilisateurs de twitter viennes noté leurs chien avec humour. La particularité de #WeRateDogs est que que la note du numérateur est supérieur à 10 alors que le dénominateur est toujours égale à 10 parce que "Ce sont de bons chiens Brent" selons #WeRateDogs.

# %% [markdown]
# ### 1. Stockage des données
#
# > Nous avons enregistrer l'ensemble de données principal collecté, évalué et nettoyé dans un fichier CSV nommé "twitter_archive_master.csv"

# %% [markdown]
# ### 2. Analyse et visualisation des données
#
# > Dans cette section, nous avons analyser et visualiser nos données qu'on préparés.
#
# > Nous avons pu conlure:
#
# - le poucentage des différent stage de chien
#
# - la relation entre le nombre de retweets et le nombre de favoris
#
# - Le nombre de différentes sources de tweet

# %% [markdown]
# #### A. le poucentage des différent stage de chien
#
# > Nous avons tracé un Diagramme circulaire de la colonne 'dog_stage'

# %% [markdown]
# ![pie.png](attachment:pie.png)

# %% [markdown]
# > On a emis des conclusions en disant que :
#
# - On voit que c'est le satge Pupper qui occupe la majorité environ(68,2%)
#
# - On voit aussi que c'est les stage Floofer qui occupe la minorité environ(0,9%)

# %% [markdown]
# #### la relation entre le nombre de retweets et le nombre de favoris
#
# > Pour voir si il y a une relation ou pas nous avons choisi de faire un Nuage de point entre le nombre de retweet et le nombre de favoris.

# %% [markdown]
# ![scat.png](attachment:scat.png)

# %% [markdown]
# > Au vu du graphique , on en déduit que Il y a une forte corrélation positve entre le nombre de retweet et le nombre de favoris

# %% [markdown]
# #### Le nombre de différentes sources de tweet
#
# > Pour ça on a décider de tracer un dragramme en baton

# %% [markdown]
# ![bar.png](attachment:bar.png)

# %% [markdown]
# > Nous en avons déduit que la plus part des tweet viennent des IPhones
